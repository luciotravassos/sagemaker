# %%
import ftplib
from ftplib import FTP
import os

# %%
#alterando o diretorio, para ficar fora daquele de onde o Jupyter Notebook foi inicializado
os.chdir(r'C:\scripts\Planilhas')

# %%
#Dados
username = 'a72742'
senha = 'Ljt31071'

# %%
# Acessando o servidor
ftp = FTP('10.198.19.24')

# %%
#Conectando
ftp.login(user= username, passwd = senha)

# %%
ftp.cwd('/tmp/')

# %%
ftp.pwd()

# %%
ftp.dir('*.nmon')

# %%
ftp.dir('awr*.html')

# %%
#file = input('Informe o nome do arquivo :')

# %%
def download():
    filename = 'ABRLPORADP05_201019_2023.nmon'
    localfile = open(filename, 'wb')
    ftp.retrbinary('RETR ' + filename, localfile.write, 1024)
    print(f'Download do arquivo {filename} concluido com sucesso !!!')
    ftp.quit()
    localfile.close()
    ftp.close()

# %%
download()

# %%
ftp.close()
